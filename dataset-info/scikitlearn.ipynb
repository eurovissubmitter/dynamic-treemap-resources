# %% [markdown]
# # Dataset analysis
# To generate results for every dataset in the `dataset` folder, run:
# ```
# for dataset in $(find dataset/* -maxdepth 0 -type d); do papermill dataset-info/DatasetBase.ipynb dataset-info/$(basename $dataset).ipynb -p input_dir $dataset; done
# ```

# %%
import matplotlib.pyplot as plt
import re, os
import papermill as pm
# %matplotlib inline

# %%
# Parameters
input_dir = "dataset/scikitlearn"

# %%
# Make a regex to extract dataset name
import re

matchObj = re.match( r'.*/(.*)', input_dir, re.M|re.I)
if matchObj:
    dataset_id = matchObj.group(1)
    dataset_id

# %%
def natural_sort(l):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %%
# List files in input_dir in natural order
files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]
files = natural_sort(files)
files[0:5]
# Out:
# ['dataset/scikitlearn/2010_01_29_fca4eb015275be4a0af8ce4af8f633eff3ef8594.csv',
#  'dataset/scikitlearn/2010_02_05_677c6fb50cd4ca4cf26e8ce2a569bcef8da7f87b.csv',
#  'dataset/scikitlearn/2010_03_30_b5e024cd84bbc6b90c8f152b880323147505ccc2.csv',
#  'dataset/scikitlearn/2010_04_30_f3af695b67f8db871f8522f4281c4c97b5b24174.csv',
#  'dataset/scikitlearn/2010_05_31_d107671df0754408744b969cbe45502fe45f139d.csv']

# %%
import pandas as pd
n_revisions = len(files)
dfs = [pd.read_csv(file) for file in files]

# %%
dfs[0].head()
# Out:
#                                                   id  weight
# 0  ikits/learn/datasets/pendigits/training/pendig...    6509
# 1              ikits/learn/datasets/german/german.py    4086
# 2  ikits/learn/datasets/pendigits/testing/pendigi...    3037
# 3        ikits/learn/machine/svm/libsvm-2.82/svm.cpp    3075
# 4  ikits/learn/machine/manifold_learning/src/matr...    1142

# %%
from functools import reduce
# Outer join of files  
df_full = reduce((lambda x, y: pd.merge(x, y, how='outer', on='id')), dfs)

# %%
# Rename columns
df_full.columns = ['id'] + ['t'+str(i) for i in range(df_full.shape[1]-1)]

# %%
df_full.head()
# Out:
#                                                   id      t0      t1  t2  t3  \
# 0  ikits/learn/datasets/pendigits/training/pendig...  6509.0  6509.0 NaN NaN
# 1              ikits/learn/datasets/german/german.py  4086.0  4086.0 NaN NaN
# 2  ikits/learn/datasets/pendigits/testing/pendigi...  3037.0  3037.0 NaN NaN
# 3        ikits/learn/machine/svm/libsvm-2.82/svm.cpp  3075.0     NaN NaN NaN
# 4  ikits/learn/machine/manifold_learning/src/matr...  1142.0     NaN NaN NaN
#
#    t4  t5  t6  t7  t8 ...   t78  t79  t80  t81  t82  t83  t84  t85  t86  t87
# 0 NaN NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1 NaN NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2 NaN NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3 NaN NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4 NaN NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 89 columns]

# %%
from collections import defaultdict
import networkx as nx

FILE_MARKER = '<files>'

def attach(branch, trunk):
    parts = branch.split('/', 1)
    if len(parts) == 1:  # branch is a file
        trunk[FILE_MARKER].append(parts[0])
    else:
        node, others = parts
        if node not in trunk:
            trunk[node] = defaultdict(dict, ((FILE_MARKER, []),))
        attach(others, trunk[node])

def build_adjacency_list(d, id, result):
    for key in d.keys():
        if key != FILE_MARKER:
            result.append((id, id + key))
            build_adjacency_list(d[key], id + key, result)
        else:
            for file in d[key]:
                result.append((id, id + file))

        
def plot_tree(id_list):
    
    keys = sorted(id_list)

    main_dict = defaultdict(dict, ((FILE_MARKER, []),))
    for line in keys:
        attach(line, main_dict)

    # _create adjacency list
    result = []
    build_adjacency_list(main_dict, "ROOT", result)

    G = nx.DiGraph()
    G.add_edges_from(result)
    # write dot file to use with graphviz
    # run "dot -_tpng test.dot >test.png"
    # nx.nx_agraph.write_dot(_g, 'test.dot')

    # same layout using matplotlib with no labels
    pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
    nx.draw(G, pos, with_labels=False, arrows=False, node_size=2)

# %% [markdown]
# ## Union tree of all revisions

# %%
tree_fig = plt.figure(0)
tree_fig.suptitle(dataset_id)
plt.axis('off')
plot_tree(df_full['id'].tolist())
#pm.display('tree', tree_fig)

# %% [markdown]
# # Evolution

# %% [markdown]
# ## Items count

# %%
def plot_item_count():
    n_items = [len(df) for df in dfs]
    plt.plot(n_items)

fig = plt.figure()
fig.suptitle("Item count")
plt.ylabel('Number of items')
plt.xlabel('Revision')

plot_item_count()

# %% [markdown]
# ## Weight count

# %%
def plot_weight():
    total_weight = [sum(df['weight']) for df in dfs]
    plt.plot(total_weight)

fig = plt.figure()
fig.suptitle("Weight evolution")
plt.ylabel('Total weight')
plt.xlabel('Revision')
plot_weight()

# %% [markdown]
# ## Addition and removal of items

# %%
# How to find removals
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="left_only"')
# Out:
#                                                     id  weight_x  weight_y  \
# 3          ikits/learn/machine/svm/libsvm-2.82/svm.cpp    3075.0       NaN
# 4    ikits/learn/machine/manifold_learning/src/matr...    1142.0       NaN
# 5    ikits/learn/machine/manifold_learning/src/matr...    1343.0       NaN
# 6    ikits/learn/machine/manifold_learning/src/matr...    1299.0       NaN
# 7    ikits/learn/machine/manifold_learning/src/matr...     873.0       NaN
# 8    ikits/learn/machine/manifold_learning/src/matr...     776.0       NaN
# 11               ikits/learn/machine/em/src/pure_den.c     461.0       NaN
# 12   ikits/learn/machine/manifold_learning/src/matr...     676.0       NaN
# 13   ikits/learn/machine/manifold_learning/src/matr...     647.0       NaN
# 14                 ikits/learn/machine/em/gauss_mix.py     728.0       NaN
# 15   ikits/learn/machine/manifold_learning/src/matr...     531.0       NaN
# 16   ikits/learn/machine/manifold_learning/src/matr...     548.0       NaN
# 17   ikits/learn/machine/manifold_learning/src/matr...     486.0       NaN
# 18   ikits/learn/machine/svm/tests/test_classificat...     307.0       NaN
# 19                    ikits/learn/machine/em/gmm_em.py     519.0       NaN
# 20   ikits/learn/machine/manifold_learning/src/matr...     431.0       NaN
# 21                  ikits/learn/machine/svm/predict.py     230.0       NaN
# 23                 ikits/learn/machine/em/online_em.py     466.0       NaN
# 24   ikits/learn/machine/manifold_learning/src/matr...     217.0       NaN
# 25   ikits/learn/machine/manifold_learning/regressi...     273.0       NaN
# 26    ikits/learn/machine/svm/tests/test_regression.py     173.0       NaN
# 27      ikits/learn/machine/em/tests/test_online_em.py     230.0       NaN
# 28                  ikits/learn/machine/svm/dataset.py     194.0       NaN
# 29   ikits/learn/machine/em/profile_data/profile_on...     241.0       NaN
# 30      ikits/learn/machine/em/tests/test_densities.py     240.0       NaN
# 32         ikits/learn/machine/em/tests/test_gmm_em.py     198.0       NaN
# 34   ikits/learn/machine/manifold_learning/src/matr...     238.0       NaN
# 35   ikits/learn/machine/manifold_learning/src/matr...     256.0       NaN
# 36                 ikits/learn/machine/em/densities.py     307.0       NaN
# 37   ikits/learn/machine/manifold_learning/src/matr...     193.0       NaN
# ..                                                 ...       ...       ...
# 156  ikits/learn/machine/em/examples/basic_example1.py      48.0       NaN
# 157      ikits/learn/machine/em/tests/test_examples.py      22.0       NaN
# 158  ikits/learn/machine/manifold_learning/stats/ke...      38.0       NaN
# 159  ikits/learn/machine/manifold_learning/compress...      43.0       NaN
# 160  ikits/learn/machine/manifold_learning/stats/se...      16.0       NaN
# 161  ikits/learn/machine/manifold_learning/compress...      15.0       NaN
# 162  ikits/learn/machine/manifold_learning/regressi...      15.0       NaN
# 164  ikits/learn/machine/manifold_learning/regressi...      17.0       NaN
# 165  ikits/learn/machine/manifold_learning/compress...      19.0       NaN
# 166                       ikits/learn/machine/setup.py      12.0       NaN
# 168         ikits/learn/machine/em/profile_data/gden.m      10.0       NaN
# 169                   ikits/learn/machine/ann/setup.py      17.0       NaN
# 171  ikits/learn/machine/manifold_learning/stats/ke...      17.0       NaN
# 172     ikits/learn/machine/em/profile_data/mat_prof.m      11.0       NaN
# 173  ikits/learn/machine/manifold_learning/projecti...      20.0       NaN
# 176                ikits/learn/machine/svm/__init__.py      67.0       NaN
# 179  ikits/learn/machine/manifold_learning/stats/__...      16.0       NaN
# 180          ikits/learn/machine/svm/tests/test_all.py       6.0       NaN
# 185  ikits/learn/machine/manifold_learning/projecti...      14.0       NaN
# 186  ikits/learn/machine/manifold_learning/regressi...      14.0       NaN
# 187  ikits/learn/machine/manifold_learning/regressi...      15.0       NaN
# 188                 ikits/learn/machine/em/__init__.py      10.0       NaN
# 190                     ikits/learn/machine/em/info.py      68.0       NaN
# 191  ikits/learn/machine/manifold_learning/__init__.py      11.0       NaN
# 192  ikits/learn/machine/manifold_learning/compress...      10.0       NaN
# 194  ikits/learn/machine/manifold_learning/compress...      10.0       NaN
# 195  ikits/learn/machine/manifold_learning/regressi...      11.0       NaN
# 197         ikits/learn/machine/em/tests/testcommon.py       1.0       NaN
# 198                ikits/learn/machine/ann/__init__.py      14.0       NaN
# 201           ikits/learn/machine/em/tests/__init__.py       1.0       NaN
#
#         _merge
# 3    left_only
# 4    left_only
# 5    left_only
# 6    left_only
# 7    left_only
# 8    left_only
# 11   left_only
# 12   left_only
# 13   left_only
# 14   left_only
# 15   left_only
# 16   left_only
# 17   left_only
# 18   left_only
# 19   left_only
# 20   left_only
# 21   left_only
# 23   left_only
# 24   left_only
# 25   left_only
# 26   left_only
# 27   left_only
# 28   left_only
# 29   left_only
# 30   left_only
# 32   left_only
# 34   left_only
# 35   left_only
# 36   left_only
# 37   left_only
# ..         ...
# 156  left_only
# 157  left_only
# 158  left_only
# 159  left_only
# 160  left_only
# 161  left_only
# 162  left_only
# 164  left_only
# 165  left_only
# 166  left_only
# 168  left_only
# 169  left_only
# 171  left_only
# 172  left_only
# 173  left_only
# 176  left_only
# 179  left_only
# 180  left_only
# 185  left_only
# 186  left_only
# 187  left_only
# 188  left_only
# 190  left_only
# 191  left_only
# 192  left_only
# 194  left_only
# 195  left_only
# 197  left_only
# 198  left_only
# 201  left_only
#
# [153 rows x 4 columns]

# %%
# How to find additions
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="right_only"')
# len(pd.merge...) to get the number of additions/deletions
# Out:
#                                                     id  weight_x  weight_y  \
# 202                ikits/learn/svm/libsvm-2.82/svm.cpp       NaN    3075.0
# 203  ikits/learn/manifold/src/matrix/matrix_functio...       NaN    1142.0
# 204  ikits/learn/manifold/src/matrix/dynamic_contai...       NaN    1343.0
# 205             ikits/learn/neighbors/src/BallTree.cpp       NaN     840.0
# 206  ikits/learn/manifold/src/matrix/expression_tem...       NaN    1299.0
# 207      ikits/learn/manifold/src/matrix/type_traits.h       NaN     873.0
# 208  ikits/learn/manifold/src/matrix/expression_tem...       NaN     776.0
# 209                      ikits/learn/em/src/pure_den.c       NaN     461.0
# 210               ikits/learn/neighbors/src/BallTree.h       NaN     591.0
# 211  ikits/learn/manifold/src/matrix/sub_vector_mat...       NaN     676.0
# 212  ikits/learn/manifold/src/matrix/iterator_based...       NaN     647.0
# 213                        ikits/learn/em/gauss_mix.py       NaN     728.0
# 214  ikits/learn/manifold/src/matrix/sub_vector_mat...       NaN     531.0
# 215   ikits/learn/manifold/src/matrix/sub_matrix_lib.h       NaN     548.0
# 216       ikits/learn/manifold/src/matrix/matrix_lib.h       NaN     486.0
# 217       ikits/learn/svm/tests/test_classification.py       NaN     307.0
# 218                           ikits/learn/em/gmm_em.py       NaN     519.0
# 219  ikits/learn/manifold/src/matrix/static_contain...       NaN     431.0
# 220                         ikits/learn/svm/predict.py       NaN     230.0
# 221                        ikits/learn/em/online_em.py       NaN     466.0
# 222        ikits/learn/manifold/src/matrix/inversion.h       NaN     217.0
# 223            ikits/learn/manifold/regression/PLMR.py       NaN     273.0
# 224           ikits/learn/svm/tests/test_regression.py       NaN     173.0
# 225             ikits/learn/em/tests/test_online_em.py       NaN     230.0
# 226                         ikits/learn/svm/dataset.py       NaN     194.0
# 227   ikits/learn/em/profile_data/profile_online_em.py       NaN     241.0
# 228             ikits/learn/em/tests/test_densities.py       NaN     240.0
# 229                ikits/learn/em/tests/test_gmm_em.py       NaN     198.0
# 230          ikits/learn/neighbors/src/BallTreePoint.h       NaN     161.0
# 231   ikits/learn/manifold/src/matrix/pointer_matrix.h       NaN     238.0
# ..                                                 ...       ...       ...
# 330  ikits/learn/manifold/compression/cost_function...       NaN      18.0
# 331           ikits/learn/manifold/stats/kernels/gm.py       NaN      38.0
# 332   ikits/learn/manifold/regression/cluster/setup.py       NaN      17.0
# 333           ikits/learn/manifold/regression/setup.py       NaN      15.0
# 334                ikits/learn/manifold/stats/setup.py       NaN      16.0
# 335                      ikits/learn/manifold/setup.py       NaN      14.0
# 336  ikits/learn/manifold/compression/similarities_...       NaN      43.0
# 337          ikits/learn/manifold/compression/setup.py       NaN      13.0
# 338  ikits/learn/manifold/regression/cluster/cluste...       NaN      17.0
# 339       ikits/learn/manifold/compression/__init__.py       NaN      19.0
# 340                 ikits/learn/em/profile_data/gden.m       NaN      10.0
# 341     ikits/learn/manifold/stats/kernels/__init__.py       NaN      17.0
# 342             ikits/learn/em/profile_data/mat_prof.m       NaN      11.0
# 343                           ikits/learn/ann/setup.py       NaN       9.0
# 344                        ikits/learn/svm/__init__.py       NaN      68.0
# 345             ikits/learn/manifold/stats/__init__.py       NaN      16.0
# 346                  ikits/learn/svm/tests/test_all.py       NaN       6.0
# 347  ikits/learn/manifold/projection/grid_MAP_proje...       NaN      20.0
# 348        ikits/learn/manifold/regression/__init__.py       NaN      14.0
# 349                         ikits/learn/em/__init__.py       NaN      10.0
# 350        ikits/learn/manifold/projection/__init__.py       NaN      14.0
# 351                             ikits/learn/em/info.py       NaN      68.0
# 352                   ikits/learn/manifold/__init__.py       NaN      11.0
# 353   ikits/learn/manifold/compression/NLM/__init__.py       NaN      10.0
# 354  ikits/learn/manifold/compression/cost_function...       NaN      10.0
# 355  ikits/learn/manifold/regression/cluster/__init...       NaN      11.0
# 356                  ikits/learn/neighbors/__init__.py       NaN       1.0
# 357                 ikits/learn/em/tests/testcommon.py       NaN       1.0
# 358                        ikits/learn/ann/__init__.py       NaN      14.0
# 359                   ikits/learn/em/tests/__init__.py       NaN       1.0
#
#          _merge
# 202  right_only
# 203  right_only
# 204  right_only
# 205  right_only
# 206  right_only
# 207  right_only
# 208  right_only
# 209  right_only
# 210  right_only
# 211  right_only
# 212  right_only
# 213  right_only
# 214  right_only
# 215  right_only
# 216  right_only
# 217  right_only
# 218  right_only
# 219  right_only
# 220  right_only
# 221  right_only
# 222  right_only
# 223  right_only
# 224  right_only
# 225  right_only
# 226  right_only
# 227  right_only
# 228  right_only
# 229  right_only
# 230  right_only
# 231  right_only
# ..          ...
# 330  right_only
# 331  right_only
# 332  right_only
# 333  right_only
# 334  right_only
# 335  right_only
# 336  right_only
# 337  right_only
# 338  right_only
# 339  right_only
# 340  right_only
# 341  right_only
# 342  right_only
# 343  right_only
# 344  right_only
# 345  right_only
# 346  right_only
# 347  right_only
# 348  right_only
# 349  right_only
# 350  right_only
# 351  right_only
# 352  right_only
# 353  right_only
# 354  right_only
# 355  right_only
# 356  right_only
# 357  right_only
# 358  right_only
# 359  right_only
#
# [158 rows x 4 columns]

# %%
fig, ax = plt.subplots()

n_additions = []
n_removals = []
for i in range(1, n_revisions):
    n_additions.append(
        len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="right_only"')))
    n_removals.append(
        -len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="left_only"')))
x = range(0, n_revisions - 1)
ax.bar(x ,n_additions, width=1, color='b')
ax.bar(x, n_removals, width=1, color='r')

fig.suptitle("Item change evolution")
plt.ylabel('Removals - Additions')
plt.xlabel('Revision')

# %% [markdown]
# ## Sum of cell's change in weight (stability)

# %%
fig = plt.figure()
change = [0.0] * n_revisions
for index, row in df_full.fillna(0).iterrows():
    for j in range (2, len(row)):
        change[j-1] += abs(row[j] - row[j-1])

plt.plot(change)
fig.suptitle("Instability")
plt.ylabel('Weight change')
plt.xlabel('Revision')
