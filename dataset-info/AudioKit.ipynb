# %% [markdown]
# # Dataset analysis
# To generate results for every dataset in the `dataset` folder, run:
# ```
# for dataset in $(find dataset/* -maxdepth 0 -type d); do papermill dataset-info/DatasetBase.ipynb dataset-info/$(basename $dataset).ipynb -p input_dir $dataset; done
# ```

# %%
import matplotlib.pyplot as plt
import re, os
import papermill as pm
# %matplotlib inline

# %%
# Parameters
input_dir = "dataset/AudioKit"

# %%
# Make a regex to extract dataset name
import re

matchObj = re.match( r'.*/(.*)', input_dir, re.M|re.I)
if matchObj:
    dataset_id = matchObj.group(1)
    dataset_id

# %%
def natural_sort(l):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %%
# List files in input_dir in natural order
files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]
files = natural_sort(files)
files[0:5]
# Out:
# ['dataset/AudioKit/2015_09_21_ba9f2436bf7fcf2367b02534cc616d772a4d9603.csv',
#  'dataset/AudioKit/2015_10_30_1e9248a4580ece6946f7db98cd76828eae334dee.csv',
#  'dataset/AudioKit/2015_11_30_ad03c37ce9698ace6c33e6d141573059a6ba6cd4.csv',
#  'dataset/AudioKit/2015_12_31_38adea1c089c1e77637075c2bf52f9b0702aa401.csv',
#  'dataset/AudioKit/2016_01_31_5854c4e951d53697c415109fb583bf4d36aed6c8.csv']

# %%
import pandas as pd
n_revisions = len(files)
dfs = [pd.read_csv(file) for file in files]

# %%
dfs[0].head()
# Out:
#                              id  weight
# 0    veloperTools/data2yaml.lua      97
# 1   veloperTools/yaml/fosc.yaml      71
# 2   veloperTools/yaml/drip.yaml      66
# 3  veloperTools/yaml/gbuzz.yaml      56
# 4   veloperTools/yaml/tenv.yaml      48

# %%
from functools import reduce
# Outer join of files  
df_full = reduce((lambda x, y: pd.merge(x, y, how='outer', on='id')), dfs)

# %%
# Rename columns
df_full.columns = ['id'] + ['t'+str(i) for i in range(df_full.shape[1]-1)]

# %%
df_full.head()
# Out:
#                              id    t0    t1     t2     t3  t4  t5  t6  t7  t8  \
# 0    veloperTools/data2yaml.lua  97.0  98.0  102.0  102.0 NaN NaN NaN NaN NaN
# 1   veloperTools/yaml/fosc.yaml  71.0   NaN    NaN    NaN NaN NaN NaN NaN NaN
# 2   veloperTools/yaml/drip.yaml  66.0   NaN    NaN    NaN NaN NaN NaN NaN NaN
# 3  veloperTools/yaml/gbuzz.yaml  56.0   NaN    NaN    NaN NaN NaN NaN NaN NaN
# 4   veloperTools/yaml/tenv.yaml  48.0   NaN    NaN    NaN NaN NaN NaN NaN NaN
#
#   ...   t12  t13  t14  t15  t16  t17  t18  t19  t20  t21
# 0 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4 ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 23 columns]

# %%
from collections import defaultdict
import networkx as nx

FILE_MARKER = '<files>'

def attach(branch, trunk):
    parts = branch.split('/', 1)
    if len(parts) == 1:  # branch is a file
        trunk[FILE_MARKER].append(parts[0])
    else:
        node, others = parts
        if node not in trunk:
            trunk[node] = defaultdict(dict, ((FILE_MARKER, []),))
        attach(others, trunk[node])

def build_adjacency_list(d, id, result):
    for key in d.keys():
        if key != FILE_MARKER:
            result.append((id, id + key))
            build_adjacency_list(d[key], id + key, result)
        else:
            for file in d[key]:
                result.append((id, id + file))

        
def plot_tree(id_list):
    
    keys = sorted(id_list)

    main_dict = defaultdict(dict, ((FILE_MARKER, []),))
    for line in keys:
        attach(line, main_dict)

    # _create adjacency list
    result = []
    build_adjacency_list(main_dict, "ROOT", result)

    G = nx.DiGraph()
    G.add_edges_from(result)
    # write dot file to use with graphviz
    # run "dot -_tpng test.dot >test.png"
    # nx.nx_agraph.write_dot(_g, 'test.dot')

    # same layout using matplotlib with no labels
    pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
    nx.draw(G, pos, with_labels=False, arrows=False, node_size=2)

# %% [markdown]
# ## Union tree of all revisions

# %%
tree_fig = plt.figure(0)
tree_fig.suptitle(dataset_id)
plt.axis('off')
plot_tree(df_full['id'].tolist())
#pm.display('tree', tree_fig)

# %% [markdown]
# # Evolution

# %% [markdown]
# ## Items count

# %%
def plot_item_count():
    n_items = [len(df) for df in dfs]
    plt.plot(n_items)

fig = plt.figure()
fig.suptitle("Item count")
plt.ylabel('Number of items')
plt.xlabel('Revision')

plot_item_count()

# %% [markdown]
# ## Weight count

# %%
def plot_weight():
    total_weight = [sum(df['weight']) for df in dfs]
    plt.plot(total_weight)

fig = plt.figure()
fig.suptitle("Weight evolution")
plt.ylabel('Total weight')
plt.xlabel('Revision')
plot_weight()

# %% [markdown]
# ## Addition and removal of items

# %%
# How to find removals
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="left_only"')
# Out:
#                                                    id  weight_x  weight_y  \
# 1                         veloperTools/yaml/fosc.yaml      71.0       NaN
# 2                         veloperTools/yaml/drip.yaml      66.0       NaN
# 3                        veloperTools/yaml/gbuzz.yaml      56.0       NaN
# 4                         veloperTools/yaml/tenv.yaml      48.0       NaN
# 5                         veloperTools/yaml/comb.yaml      47.0       NaN
# 6                        veloperTools/yaml/scale.yaml      42.0       NaN
# 7                   veloperTools/yaml/pareq-low1.yaml      43.0       NaN
# 8               veloperTools/yaml/pareq-peaking0.yaml      43.0       NaN
# 9                  veloperTools/yaml/pareq-high2.yaml      43.0       NaN
# 10                        veloperTools/yaml/dist.yaml      39.0       NaN
# 11                       veloperTools/yaml/eqfil.yaml      40.0       NaN
# 12                         veloperTools/yaml/osc.yaml      39.0       NaN
# 13                       veloperTools/yaml/randi.yaml      38.0       NaN
# 14                        veloperTools/yaml/clip.yaml      40.0       NaN
# 15                       veloperTools/yaml/lpf18.yaml      36.0       NaN
# 16                      veloperTools/yaml/fofilt.yaml      36.0       NaN
# 17                      veloperTools/yaml/jitter.yaml      36.0       NaN
# 18                       veloperTools/yaml/revsc.yaml      35.0       NaN
# 19                     veloperTools/yaml/allpass.yaml      35.0       NaN
# 20                       veloperTools/yaml/tenv2.yaml      34.0       NaN
# 21                       veloperTools/yaml/panst.yaml      35.0       NaN
# 22                  veloperTools/yaml/moogladder.yaml      31.0       NaN
# 23                       veloperTools/yaml/butbr.yaml      32.0       NaN
# 24                       veloperTools/yaml/delay.yaml      33.0       NaN
# 25                       veloperTools/yaml/butbp.yaml      32.0       NaN
# 26                        veloperTools/yaml/mode.yaml      32.0       NaN
# 27                     veloperTools/yaml/streson.yaml      31.0       NaN
# 28                      veloperTools/yaml/vdelay.yaml      33.0       NaN
# 29                   veloperTools/yaml/decimator.yaml      31.0       NaN
# 30                         veloperTools/yaml/bal.yaml      28.0       NaN
# 31                     veloperTools/yaml/reverse.yaml      28.0       NaN
# 32                         veloperTools/yaml/rms.yaml      28.0       NaN
# 33                       veloperTools/yaml/buthp.yaml      27.0       NaN
# 34                        veloperTools/yaml/port.yaml      27.0       NaN
# 36                       veloperTools/yaml/butlp.yaml      27.0       NaN
# 37                      veloperTools/yaml/phasor.yaml      26.0       NaN
# 38  iftOSXProofOfConcept/SwiftOSXProofOfConcept/AK...      29.0       NaN
# 39                      veloperTools/yaml/random.yaml      25.0       NaN
# 40                       veloperTools/yaml/jcrev.yaml      25.0       NaN
# 41                        veloperTools/yaml/tone.yaml      26.0       NaN
# 42                       veloperTools/yaml/atone.yaml      26.0       NaN
# 43                       veloperTools/yaml/metro.yaml      20.0       NaN
# 44                     veloperTools/yaml/dcblock.yaml      18.0       NaN
# 45                       veloperTools/yaml/noise.yaml      19.0       NaN
# 46          dioKit/Engine/AKAudioUnitRenderCallback.h      19.0       NaN
# 50  iftOSXProofOfConcept/SwiftOSXProofOfConcept/Sw...      12.0       NaN
#
#        _merge
# 1   left_only
# 2   left_only
# 3   left_only
# 4   left_only
# 5   left_only
# 6   left_only
# 7   left_only
# 8   left_only
# 9   left_only
# 10  left_only
# 11  left_only
# 12  left_only
# 13  left_only
# 14  left_only
# 15  left_only
# 16  left_only
# 17  left_only
# 18  left_only
# 19  left_only
# 20  left_only
# 21  left_only
# 22  left_only
# 23  left_only
# 24  left_only
# 25  left_only
# 26  left_only
# 27  left_only
# 28  left_only
# 29  left_only
# 30  left_only
# 31  left_only
# 32  left_only
# 33  left_only
# 34  left_only
# 36  left_only
# 37  left_only
# 38  left_only
# 39  left_only
# 40  left_only
# 41  left_only
# 42  left_only
# 43  left_only
# 44  left_only
# 45  left_only
# 46  left_only
# 50  left_only

# %%
# How to find additions
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="right_only"')
# len(pd.merge...) to get the number of additions/deletions
# Out:
#                                                     id  weight_x  weight_y  \
# 52     dioKit/AudioKit/Internals/Soundpipe/soundpipe.h       NaN     447.0
# 53   dioKit/AudioKit/Internals/Soundpipe/modules/jc...       NaN     327.0
# 54   dioKit/AudioKit/Internals/Soundpipe/modules/ft...       NaN     255.0
# 55   dioKit/AudioKit/Internals/Soundpipe/modules/re...       NaN     276.0
# 56   dioKit/AudioKit/Operations/Signal Generators/O...       NaN     273.0
# 57   dioKit/AudioKit/Internals/Soundpipe/modules/ba...       NaN     190.0
# 58   dioKit/AudioKit/Operations/Math/AKLinearTransf...       NaN     258.0
# 59   dioKit/AudioKit/Operations/Signal Modifiers/Ef...       NaN     258.0
# 60   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     258.0
# 61   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     243.0
# 62   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     243.0
# 63   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     243.0
# 64   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     243.0
# 65   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     243.0
# 66   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     243.0
# 67   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     243.0
# 68   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     228.0
# 69   dioKit/AudioKit/Operations/Signal Generators/O...       NaN     228.0
# 70   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     228.0
# 71   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     228.0
# 72   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     228.0
# 73   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     228.0
# 74   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     228.0
# 75   dioKit/AudioKit/Internals/Soundpipe/lib/inih/i...       NaN     185.0
# 76   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     213.0
# 77   dioKit/AudioKit/Operations/Analysis/AKTrackedA...       NaN     213.0
# 78   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     213.0
# 79   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     213.0
# 80   dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN     213.0
# 81   dioKit/AudioKit/Operations/Signal Modifiers/De...       NaN     213.0
# ..                                                 ...       ...       ...
# 202  dioKit/AudioKit/Operations/Signal Generators/O...       NaN      17.0
# 203  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 204  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 205  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 206  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 207  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 208  dioKit/AudioKit/Operations/Signal Modifiers/De...       NaN      17.0
# 209  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 210  dioKit/AudioKit/Operations/Signal Modifiers/Re...       NaN      17.0
# 211  dioKit/AudioKit/Operations/Signal Modifiers/De...       NaN      17.0
# 212  dioKit/AudioKit/Operations/Math/AKLinearTransf...       NaN      17.0
# 213  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 214  dioKit/AudioKit/Operations/Analysis/AKTrackedA...       NaN      17.0
# 215  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 216  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 217  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 218  dioKit/AudioKit/Operations/Signal Generators/O...       NaN      17.0
# 219  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 220  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 221  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 222  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 223  dioKit/AudioKit/Operations/Signal Generators/R...       NaN      17.0
# 224  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 225  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 226  dioKit/AudioKit/Operations/Signal Modifiers/Re...       NaN      17.0
# 227  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 228  dioKit/AudioKit/Operations/Signal Generators/O...       NaN      17.0
# 229  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 230  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
# 231  dioKit/AudioKit/Operations/Signal Modifiers/Fi...       NaN      17.0
#
#          _merge
# 52   right_only
# 53   right_only
# 54   right_only
# 55   right_only
# 56   right_only
# 57   right_only
# 58   right_only
# 59   right_only
# 60   right_only
# 61   right_only
# 62   right_only
# 63   right_only
# 64   right_only
# 65   right_only
# 66   right_only
# 67   right_only
# 68   right_only
# 69   right_only
# 70   right_only
# 71   right_only
# 72   right_only
# 73   right_only
# 74   right_only
# 75   right_only
# 76   right_only
# 77   right_only
# 78   right_only
# 79   right_only
# 80   right_only
# 81   right_only
# ..          ...
# 202  right_only
# 203  right_only
# 204  right_only
# 205  right_only
# 206  right_only
# 207  right_only
# 208  right_only
# 209  right_only
# 210  right_only
# 211  right_only
# 212  right_only
# 213  right_only
# 214  right_only
# 215  right_only
# 216  right_only
# 217  right_only
# 218  right_only
# 219  right_only
# 220  right_only
# 221  right_only
# 222  right_only
# 223  right_only
# 224  right_only
# 225  right_only
# 226  right_only
# 227  right_only
# 228  right_only
# 229  right_only
# 230  right_only
# 231  right_only
#
# [180 rows x 4 columns]

# %%
fig, ax = plt.subplots()

n_additions = []
n_removals = []
for i in range(1, n_revisions):
    n_additions.append(
        len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="right_only"')))
    n_removals.append(
        -len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="left_only"')))
x = range(0, n_revisions - 1)
ax.bar(x ,n_additions, width=1, color='b')
ax.bar(x, n_removals, width=1, color='r')

fig.suptitle("Item change evolution")
plt.ylabel('Removals - Additions')
plt.xlabel('Revision')

# %% [markdown]
# ## Sum of cell's change in weight (stability)

# %%
fig = plt.figure()
change = [0.0] * n_revisions
for index, row in df_full.fillna(0).iterrows():
    for j in range (2, len(row)):
        change[j-1] += abs(row[j] - row[j-1])

plt.plot(change)
fig.suptitle("Instability")
plt.ylabel('Weight change')
plt.xlabel('Revision')
