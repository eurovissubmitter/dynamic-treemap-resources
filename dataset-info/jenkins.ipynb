# %% [markdown]
# # Dataset analysis
# To generate results for every dataset in the `dataset` folder, run:
# ```
# for dataset in $(find dataset/* -maxdepth 0 -type d); do papermill dataset-info/DatasetBase.ipynb dataset-info/$(basename $dataset).ipynb -p input_dir $dataset; done
# ```

# %%
import matplotlib.pyplot as plt
import re, os
import papermill as pm
# %matplotlib inline

# %%
# Parameters
input_dir = "dataset/jenkins"

# %%
# Make a regex to extract dataset name
import re

matchObj = re.match( r'.*/(.*)', input_dir, re.M|re.I)
if matchObj:
    dataset_id = matchObj.group(1)
    dataset_id

# %%
def natural_sort(l):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %%
# List files in input_dir in natural order
files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]
files = natural_sort(files)
files[0:5]
# Out:
# ['dataset/jenkins/2006_11_24_0c96be810dcc792c7e1e54f7ab88e209b097cf3f.csv',
#  'dataset/jenkins/2006_12_31_57edca0e063b57b2e1df794bcb8954d37656051f.csv',
#  'dataset/jenkins/2007_01_31_2c05c68cba23643d6af98c745621e44bbf26e707.csv',
#  'dataset/jenkins/2007_02_28_e566bf12d54a966db1e1b6f23e84af1aae6564b8.csv',
#  'dataset/jenkins/2007_03_31_386e17aa29f3927d20d92e9e9ee3809f4f4a6022.csv']

# %%
import pandas as pd
n_revisions = len(files)
dfs = [pd.read_csv(file) for file in files]

# %%
dfs[0].head()
# Out:
#                                            id  weight
# 0            r/resources/scripts/prototype.js    1790
# 1   re/src/main/java/hudson/model/Hudson.java    1180
# 2     re/src/main/java/hudson/scm/CVSSCM.java     905
# 3      re/src/main/java/hudson/model/Run.java     843
# 4  re/src/main/java/hudson/model/Project.java     815

# %%
from functools import reduce
# Outer join of files  
df_full = reduce((lambda x, y: pd.merge(x, y, how='outer', on='id')), dfs)

# %%
# Rename columns
df_full.columns = ['id'] + ['t'+str(i) for i in range(df_full.shape[1]-1)]

# %%
df_full.head()
# Out:
#                                            id      t0      t1      t2      t3  \
# 0            r/resources/scripts/prototype.js  1790.0  1795.0  1795.0  1795.0
# 1   re/src/main/java/hudson/model/Hudson.java  1180.0  1292.0  1407.0  1448.0
# 2     re/src/main/java/hudson/scm/CVSSCM.java   905.0  1069.0  1227.0  1234.0
# 3      re/src/main/java/hudson/model/Run.java   843.0   833.0   838.0   842.0
# 4  re/src/main/java/hudson/model/Project.java   815.0   778.0   282.0   292.0
#
#        t4      t5      t6      t7      t8   ...      t127    t128    t129  \
# 0  1795.0  1795.0  1795.0  1795.0  1795.0   ...       NaN     NaN     NaN
# 1  1506.0  1539.0  1656.0  1704.0  1783.0   ...     345.0   345.0   345.0
# 2  1259.0  1303.0  1303.0  1264.0  1303.0   ...       NaN     NaN     NaN
# 3   863.0   883.0   883.0   891.0   891.0   ...    2451.0  2452.0  2449.0
# 4   278.0   277.0   277.0   230.0   181.0   ...     276.0   276.0   276.0
#
#      t130    t131    t132    t133    t134    t135    t136
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   345.0   345.0   345.0   345.0   345.0   347.0   347.0
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3  2480.0  2481.0  2478.0  2478.0  2478.0  2489.0  2489.0
# 4   276.0   276.0   276.0   276.0   276.0   276.0   276.0
#
# [5 rows x 138 columns]

# %%
from collections import defaultdict
import networkx as nx

FILE_MARKER = '<files>'

def attach(branch, trunk):
    parts = branch.split('/', 1)
    if len(parts) == 1:  # branch is a file
        trunk[FILE_MARKER].append(parts[0])
    else:
        node, others = parts
        if node not in trunk:
            trunk[node] = defaultdict(dict, ((FILE_MARKER, []),))
        attach(others, trunk[node])

def build_adjacency_list(d, id, result):
    for key in d.keys():
        if key != FILE_MARKER:
            result.append((id, id + key))
            build_adjacency_list(d[key], id + key, result)
        else:
            for file in d[key]:
                result.append((id, id + file))

        
def plot_tree(id_list):
    
    keys = sorted(id_list)

    main_dict = defaultdict(dict, ((FILE_MARKER, []),))
    for line in keys:
        attach(line, main_dict)

    # _create adjacency list
    result = []
    build_adjacency_list(main_dict, "ROOT", result)

    G = nx.DiGraph()
    G.add_edges_from(result)
    # write dot file to use with graphviz
    # run "dot -_tpng test.dot >test.png"
    # nx.nx_agraph.write_dot(_g, 'test.dot')

    # same layout using matplotlib with no labels
    pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
    nx.draw(G, pos, with_labels=False, arrows=False, node_size=2)

# %% [markdown]
# ## Union tree of all revisions

# %%
tree_fig = plt.figure(0)
tree_fig.suptitle(dataset_id)
plt.axis('off')
plot_tree(df_full['id'].tolist())
#pm.display('tree', tree_fig)

# %% [markdown]
# # Evolution

# %% [markdown]
# ## Items count

# %%
def plot_item_count():
    n_items = [len(df) for df in dfs]
    plt.plot(n_items)

fig = plt.figure()
fig.suptitle("Item count")
plt.ylabel('Number of items')
plt.xlabel('Revision')

plot_item_count()

# %% [markdown]
# ## Weight count

# %%
def plot_weight():
    total_weight = [sum(df['weight']) for df in dfs]
    plt.plot(total_weight)

fig = plt.figure()
fig.suptitle("Weight evolution")
plt.ylabel('Total weight')
plt.xlabel('Revision')
plot_weight()

# %% [markdown]
# ## Addition and removal of items

# %%
# How to find removals
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="left_only"')
# Out:
#                                                     id  weight_x  weight_y  \
# 118                                       re/bin/slave      51.0       NaN
# 131                                      re/bin/hudson      32.0       NaN
# 156  re/src/main/java/hudson/tasks/AntBasedPublishe...      23.0       NaN
# 179  r/resources/help/system-config/master-slave/lo...      11.0       NaN
#
#         _merge
# 118  left_only
# 131  left_only
# 156  left_only
# 179  left_only

# %%
# How to find additions
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="right_only"')
# len(pd.merge...) to get the number of additions/deletions
# Out:
#                                                     id  weight_x  weight_y  \
# 241         r/resources/scripts/yui/container-debug.js       NaN    4602.0
# 242    r/resources/scripts/yui/container_core-debug.js       NaN    2911.0
# 243             r/resources/scripts/yui/event-debug.js       NaN    1766.0
# 244               r/resources/scripts/yui/dom-debug.js       NaN     916.0
# 245  moting/src/main/java/hudson/remoting/Channel.java       NaN     394.0
# 246                                     moting/pom.xml       NaN     204.0
# 247              r/resources/scripts/yui/container.css       NaN     211.0
# 248           r/resources/scripts/yui/container-min.js       NaN     147.0
# 249  re/src/main/java/hudson/util/StackedAreaRender...       NaN     176.0
# 250  moting/src/main/java/hudson/remoting/RemoteInv...       NaN     176.0
# 251  moting/src/main/java/hudson/remoting/ProxyWrit...       NaN     166.0
# 252  moting/src/main/java/hudson/remoting/ProxyOutp...       NaN     160.0
# 253      r/resources/scripts/yui/container_core-min.js       NaN      99.0
# 254  moting/src/main/java/hudson/remoting/ProxyInpu...       NaN     140.0
# 255  moting/src/main/java/hudson/remoting/Request.java       NaN     192.0
# 256  moting/src/test/java/hudson/remoting/ChannelRu...       NaN     120.0
# 257     moting/src/main/java/hudson/remoting/Pipe.java       NaN     166.0
# 258  moting/src/main/java/hudson/remoting/UserReque...       NaN     102.0
# 259  moting/src/test/java/hudson/remoting/PipeTest....       NaN     104.0
# 260  re/src/main/java/hudson/tasks/test/TestResultP...       NaN     113.0
# 261  moting/src/main/java/hudson/remoting/ObjectInp...       NaN      64.0
# 262             r/resources/scripts/yui/yahoo-debug.js       NaN     145.0
# 263  moting/src/main/java/hudson/remoting/RemoteCla...       NaN      80.0
# 264  moting/src/main/java/hudson/remoting/LocalChan...       NaN      70.0
# 265  re/src/main/java/hudson/tasks/CommandInterpret...       NaN      71.0
# 266  moting/src/main/java/hudson/remoting/RemoteWri...       NaN     101.0
# 267  moting/src/test/java/hudson/remoting/DummyClas...       NaN      69.0
# 268  moting/src/main/java/hudson/remoting/RemoteInp...       NaN      74.0
# 269  moting/src/test/java/hudson/remoting/SimpleTes...       NaN      62.0
# 270  moting/src/test/java/hudson/remoting/RmiTestBa...       NaN      59.0
# ..                                                 ...       ...       ...
# 275  moting/src/main/java/hudson/remoting/FutureAda...       NaN      40.0
# 276  moting/src/main/java/hudson/remoting/ExportedC...       NaN      39.0
# 277  moting/src/test/java/hudson/remoting/CopyThrea...       NaN      33.0
# 278  moting/src/main/java/hudson/remoting/ImportedC...       NaN      33.0
# 279                         r/resources/WEB-INF/hudson       NaN      32.0
# 280  re/src/main/java/hudson/util/StreamCopyThread....       NaN      32.0
# 281                        moting/assembly-uberjar.xml       NaN      29.0
# 282                                     sembly-src.xml       NaN      22.0
# 283  re/src/main/java/hudson/util/DaemonThreadFacto...       NaN      27.0
# 284  moting/src/main/java/hudson/remoting/Launcher....       NaN      30.0
# 285  moting/src/test/java/hudson/remoting/ChannelTe...       NaN      32.0
# 286  moting/src/test/java/hudson/remoting/ClassRemo...       NaN      25.0
# 287  re/src/main/java/hudson/model/listeners/JobLis...       NaN      38.0
# 288  moting/src/main/java/hudson/remoting/UnexportC...       NaN      19.0
# 289  moting/src/test/java/hudson/remoting/DummyClas...       NaN      16.0
# 290  moting/src/main/java/hudson/remoting/VirtualCh...       NaN      63.0
# 291  re/src/main/java/hudson/tasks/junit/AbortExcep...       NaN      14.0
# 292    re/src/main/java/hudson/util/EnumConverter.java       NaN      13.0
# 293  moting/src/test/java/hudson/remoting/TestCalla...       NaN      12.0
# 294  moting/src/main/java/hudson/remoting/RequestAb...       NaN      13.0
# 295     re/src/main/java/hudson/util/ColorPalette.java       NaN      13.0
# 296  moting/src/main/java/hudson/remoting/Command.java       NaN      25.0
# 297  moting/src/main/java/hudson/remoting/Callable....       NaN      17.0
# 298  moting/src/main/java/hudson/remoting/Delegatin...       NaN      17.0
# 299  re/src/main/java/hudson/util/IncompatibleServl...       NaN      13.0
# 300   moting/src/main/java/hudson/remoting/Future.java       NaN      13.0
# 301               r/resources/scripts/yui/yahoo-min.js       NaN       1.0
# 302  moting/src/main/java/hudson/remoting/package-i...       NaN       7.0
# 303               r/resources/scripts/yui/event-min.js       NaN       1.0
# 304                 r/resources/scripts/yui/dom-min.js       NaN       1.0
#
#          _merge
# 241  right_only
# 242  right_only
# 243  right_only
# 244  right_only
# 245  right_only
# 246  right_only
# 247  right_only
# 248  right_only
# 249  right_only
# 250  right_only
# 251  right_only
# 252  right_only
# 253  right_only
# 254  right_only
# 255  right_only
# 256  right_only
# 257  right_only
# 258  right_only
# 259  right_only
# 260  right_only
# 261  right_only
# 262  right_only
# 263  right_only
# 264  right_only
# 265  right_only
# 266  right_only
# 267  right_only
# 268  right_only
# 269  right_only
# 270  right_only
# ..          ...
# 275  right_only
# 276  right_only
# 277  right_only
# 278  right_only
# 279  right_only
# 280  right_only
# 281  right_only
# 282  right_only
# 283  right_only
# 284  right_only
# 285  right_only
# 286  right_only
# 287  right_only
# 288  right_only
# 289  right_only
# 290  right_only
# 291  right_only
# 292  right_only
# 293  right_only
# 294  right_only
# 295  right_only
# 296  right_only
# 297  right_only
# 298  right_only
# 299  right_only
# 300  right_only
# 301  right_only
# 302  right_only
# 303  right_only
# 304  right_only
#
# [64 rows x 4 columns]

# %%
fig, ax = plt.subplots()

n_additions = []
n_removals = []
for i in range(1, n_revisions):
    n_additions.append(
        len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="right_only"')))
    n_removals.append(
        -len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="left_only"')))
x = range(0, n_revisions - 1)
ax.bar(x ,n_additions, width=1, color='b')
ax.bar(x, n_removals, width=1, color='r')

fig.suptitle("Item change evolution")
plt.ylabel('Removals - Additions')
plt.xlabel('Revision')

# %% [markdown]
# ## Sum of cell's change in weight (stability)

# %%
fig = plt.figure()
change = [0.0] * n_revisions
for index, row in df_full.fillna(0).iterrows():
    for j in range (2, len(row)):
        change[j-1] += abs(row[j] - row[j-1])

plt.plot(change)
fig.suptitle("Instability")
plt.ylabel('Weight change')
plt.xlabel('Revision')
