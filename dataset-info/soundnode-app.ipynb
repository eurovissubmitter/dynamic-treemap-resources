# %% [markdown]
# # Dataset analysis
# To generate results for every dataset in the `dataset` folder, run:
# ```
# for dataset in $(find dataset/* -maxdepth 0 -type d); do papermill dataset-info/DatasetBase.ipynb dataset-info/$(basename $dataset).ipynb -p input_dir $dataset; done
# ```

# %%
import matplotlib.pyplot as plt
import re, os
import papermill as pm
# %matplotlib inline

# %%
# Parameters
input_dir = "dataset/soundnode-app"

# %%
# Make a regex to extract dataset name
import re

matchObj = re.match( r'.*/(.*)', input_dir, re.M|re.I)
if matchObj:
    dataset_id = matchObj.group(1)
    dataset_id

# %%
def natural_sort(l):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %%
# List files in input_dir in natural order
files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]
files = natural_sort(files)
files[0:5]
# Out:
# ['dataset/soundnode-app/2014_04_30_b80b3ad7d999aa655639edf5ebfeeefd10d4e773.csv',
#  'dataset/soundnode-app/2014_05_31_8423570f3bed43ae57b0a696827e75f6388a6eeb.csv',
#  'dataset/soundnode-app/2014_06_19_0a4a4106f06aac8b6eb852468f4b3538140fad9e.csv',
#  'dataset/soundnode-app/2014_07_29_b2439e9ad8da7bcdbe9be2ea8d4b2aab12363623.csv',
#  'dataset/soundnode-app/2014_08_15_2d57840c8e25935d8ecdeeec160793c20b4af508.csv']

# %%
import pandas as pd
n_revisions = len(files)
dfs = [pd.read_csv(file) for file in files]

# %%
dfs[0].head()
# Out:
#                                         id  weight
# 0        v/app/public/js/vendor/angular.js   21053
# 1  v/app/public/js/vendor/angular-route.js     922
# 2   v/app/public/stylesheets/sass/app.scss     198
# 3     v/app/public/stylesheets/css/app.css     166
# 4                         v/app/index.html     117

# %%
from functools import reduce
# Outer join of files  
df_full = reduce((lambda x, y: pd.merge(x, y, how='outer', on='id')), dfs)

# %%
# Rename columns
df_full.columns = ['id'] + ['t'+str(i) for i in range(df_full.shape[1]-1)]

# %%
df_full.head()
# Out:
#                                         id       t0  t1  t2  t3  t4  t5  t6  \
# 0        v/app/public/js/vendor/angular.js  21053.0 NaN NaN NaN NaN NaN NaN
# 1  v/app/public/js/vendor/angular-route.js    922.0 NaN NaN NaN NaN NaN NaN
# 2   v/app/public/stylesheets/sass/app.scss    198.0 NaN NaN NaN NaN NaN NaN
# 3     v/app/public/stylesheets/css/app.css    166.0 NaN NaN NaN NaN NaN NaN
# 4                         v/app/index.html    117.0 NaN NaN NaN NaN NaN NaN
#
#    t7  t8 ...   t25  t26  t27  t28  t29  t30  t31  t32  t33  t34
# 0 NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1 NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2 NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3 NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4 NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 36 columns]

# %%
from collections import defaultdict
import networkx as nx

FILE_MARKER = '<files>'

def attach(branch, trunk):
    parts = branch.split('/', 1)
    if len(parts) == 1:  # branch is a file
        trunk[FILE_MARKER].append(parts[0])
    else:
        node, others = parts
        if node not in trunk:
            trunk[node] = defaultdict(dict, ((FILE_MARKER, []),))
        attach(others, trunk[node])

def build_adjacency_list(d, id, result):
    for key in d.keys():
        if key != FILE_MARKER:
            result.append((id, id + key))
            build_adjacency_list(d[key], id + key, result)
        else:
            for file in d[key]:
                result.append((id, id + file))

        
def plot_tree(id_list):
    
    keys = sorted(id_list)

    main_dict = defaultdict(dict, ((FILE_MARKER, []),))
    for line in keys:
        attach(line, main_dict)

    # _create adjacency list
    result = []
    build_adjacency_list(main_dict, "ROOT", result)

    G = nx.DiGraph()
    G.add_edges_from(result)
    # write dot file to use with graphviz
    # run "dot -_tpng test.dot >test.png"
    # nx.nx_agraph.write_dot(_g, 'test.dot')

    # same layout using matplotlib with no labels
    pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
    nx.draw(G, pos, with_labels=False, arrows=False, node_size=2)

# %% [markdown]
# ## Union tree of all revisions

# %%
tree_fig = plt.figure(0)
tree_fig.suptitle(dataset_id)
plt.axis('off')
plot_tree(df_full['id'].tolist())
#pm.display('tree', tree_fig)

# %% [markdown]
# # Evolution

# %% [markdown]
# ## Items count

# %%
def plot_item_count():
    n_items = [len(df) for df in dfs]
    plt.plot(n_items)

fig = plt.figure()
fig.suptitle("Item count")
plt.ylabel('Number of items')
plt.xlabel('Revision')

plot_item_count()

# %% [markdown]
# ## Weight count

# %%
def plot_weight():
    total_weight = [sum(df['weight']) for df in dfs]
    plt.plot(total_weight)

fig = plt.figure()
fig.suptitle("Weight evolution")
plt.ylabel('Total weight')
plt.xlabel('Revision')
plot_weight()

# %% [markdown]
# ## Addition and removal of items

# %%
# How to find removals
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="left_only"')
# Out:
#                                                    id  weight_x  weight_y  \
# 0                   v/app/public/js/vendor/angular.js   21053.0       NaN
# 1             v/app/public/js/vendor/angular-route.js     922.0       NaN
# 2              v/app/public/stylesheets/sass/app.scss     198.0       NaN
# 3                v/app/public/stylesheets/css/app.css     166.0       NaN
# 4                                    v/app/index.html     117.0       NaN
# 5                              v/app/public/js/app.js      28.0       NaN
# 6                 v/app/public/js/controllers/user.js       8.0       NaN
# 7              v/app/public/js/controllers/playing.js      14.0       NaN
# 8                  v/app/public/stylesheets/config.rb      29.0       NaN
# 9            v/app/public/js/controllers/playlists.js       5.0       NaN
# 10              v/app/public/js/controllers/tracks.js      13.0       NaN
# 11           v/app/public/js/controllers/following.js       5.0       NaN
# 12           v/app/public/js/controllers/favorites.js      13.0       NaN
# 13              v/app/public/js/controllers/stream.js      14.0       NaN
# 14               v/app/public/js/vendor/jquery.min.js       5.0       NaN
# 15                         v/app/views/playlists.html       3.0       NaN
# 16                            v/app/views/tracks.html       3.0       NaN
# 17                         v/app/views/favorites.html       3.0       NaN
# 18                           v/app/views/playing.html       3.0       NaN
# 19                         v/app/views/following.html       3.0       NaN
# 20                            v/app/views/stream.html       3.0       NaN
# 21          v/app/public/stylesheets/css/pure.min.css      11.0       NaN
# 22  v/app/public/stylesheets/css/font-awesome/css/...       4.0       NaN
# 23                             v/app/public/js/api.js      11.0       NaN
#
#        _merge
# 0   left_only
# 1   left_only
# 2   left_only
# 3   left_only
# 4   left_only
# 5   left_only
# 6   left_only
# 7   left_only
# 8   left_only
# 9   left_only
# 10  left_only
# 11  left_only
# 12  left_only
# 13  left_only
# 14  left_only
# 15  left_only
# 16  left_only
# 17  left_only
# 18  left_only
# 19  left_only
# 20  left_only
# 21  left_only
# 22  left_only
# 23  left_only

# %%
# How to find additions
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="right_only"')
# len(pd.merge...) to get the number of additions/deletions
# Out:
#                                                    id  weight_x  weight_y  \
# 24                      p/public/js/vendor/angular.js       NaN   21053.0
# 25                   p/public/stylesheets/css/app.css       NaN     859.0
# 26                p/public/js/common/playerService.js       NaN     244.0
# 27                                       p/index.html       NaN     193.0
# 28  p/public/stylesheets/sass/_components/_songlis...       NaN     109.0
# 29  p/public/stylesheets/sass/_components/_loader....       NaN      96.0
# 30               p/public/stylesheets/css/hotkeys.css       NaN     101.0
# 31  p/public/stylesheets/sass/_components/_player....       NaN      85.0
# 32  p/public/stylesheets/sass/_components/_topFram...       NaN      82.0
# 33  p/public/stylesheets/sass/_components/_aside.scss       NaN      85.0
# 34                   p/public/js/player/playerCtrl.js       NaN      77.0
# 35                                         untfile.js       NaN      70.0
# 36                         p/public/js/system/core.js       NaN     101.0
# 37                         p/views/tracks/tracks.html       NaN      53.0
# 38                         p/views/stream/stream.html       NaN      52.0
# 39                         p/views/search/search.html       NaN      51.0
# 40                   p/views/favorites/favorites.html       NaN      50.0
# 41                                 p/public/js/app.js       NaN      46.0
# 42  p/public/stylesheets/sass/_components/_default...       NaN      44.0
# 43  p/public/stylesheets/sass/_components/_appStat...       NaN      44.0
# 44                   p/views/playlists/playlists.html       NaN      47.0
# 45  p/public/stylesheets/sass/_components/_playlis...       NaN      40.0
# 46                 p/public/js/common/SCapiService.js       NaN      39.0
# 47  p/public/stylesheets/sass/_components/_search....       NaN      27.0
# 48             p/public/js/playlists/playlistsCtrl.js       NaN      27.0
# 49                 p/public/js/updater/updaterCtrl.js       NaN      24.0
# 50                       p/public/js/user/userCtrl.js       NaN      22.0
# 51    p/public/js/common/openExternalLinkDirective.js       NaN      20.0
# 52                p/public/js/common/songDirective.js       NaN      20.0
# 53                     p/public/js/about/aboutCtrl.js       NaN      20.0
# 54                 p/public/stylesheets/sass/app.scss       NaN      67.0
# 55             p/public/js/favorites/favoritesCtrl.js       NaN      17.0
# 56                   p/public/js/search/searchCtrl.js       NaN      17.0
# 57                   p/public/js/tracks/tracksCtrl.js       NaN      16.0
# 58                   p/public/js/stream/streamCtrl.js       NaN      17.0
# 59  p/public/stylesheets/sass/_components/_view-co...       NaN      15.0
# 60                      p/public/js/common/appCtrl.js       NaN      14.0
# 61  p/public/stylesheets/sass/_components/_config....       NaN       8.0
# 62  p/public/stylesheets/sass/_components/_appCont...       NaN       8.0
# 63              p/public/js/search/searchInputCtrl.js       NaN       9.0
# 64  p/public/stylesheets/sass/_components/_elIfram...       NaN       6.0
# 65                           p/views/about/about.html       NaN       6.0
# 66                     p/public/stylesheets/config.rb       NaN      29.0
# 67             p/public/js/following/followingCtrl.js       NaN       5.0
# 68                   p/views/following/following.html       NaN       3.0
# 69                   p/public/js/vendor/jquery.min.js       NaN       5.0
# 70                     p/public/js/system/settings.js       NaN       4.0
# 71        p/public/js/vendor/angular-ui-router.min.js       NaN       7.0
# 72  p/public/stylesheets/css/font-awesome/css/font...       NaN       4.0
# 73                  p/public/js/vendor/hotkeys.min.js       NaN       7.0
# 74         p/public/stylesheets/css/normalize.min.css       NaN       1.0
#
#         _merge
# 24  right_only
# 25  right_only
# 26  right_only
# 27  right_only
# 28  right_only
# 29  right_only
# 30  right_only
# 31  right_only
# 32  right_only
# 33  right_only
# 34  right_only
# 35  right_only
# 36  right_only
# 37  right_only
# 38  right_only
# 39  right_only
# 40  right_only
# 41  right_only
# 42  right_only
# 43  right_only
# 44  right_only
# 45  right_only
# 46  right_only
# 47  right_only
# 48  right_only
# 49  right_only
# 50  right_only
# 51  right_only
# 52  right_only
# 53  right_only
# 54  right_only
# 55  right_only
# 56  right_only
# 57  right_only
# 58  right_only
# 59  right_only
# 60  right_only
# 61  right_only
# 62  right_only
# 63  right_only
# 64  right_only
# 65  right_only
# 66  right_only
# 67  right_only
# 68  right_only
# 69  right_only
# 70  right_only
# 71  right_only
# 72  right_only
# 73  right_only
# 74  right_only

# %%
fig, ax = plt.subplots()

n_additions = []
n_removals = []
for i in range(1, n_revisions):
    n_additions.append(
        len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="right_only"')))
    n_removals.append(
        -len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="left_only"')))
x = range(0, n_revisions - 1)
ax.bar(x ,n_additions, width=1, color='b')
ax.bar(x, n_removals, width=1, color='r')

fig.suptitle("Item change evolution")
plt.ylabel('Removals - Additions')
plt.xlabel('Revision')

# %% [markdown]
# ## Sum of cell's change in weight (stability)

# %%
fig = plt.figure()
change = [0.0] * n_revisions
for index, row in df_full.fillna(0).iterrows():
    for j in range (2, len(row)):
        change[j-1] += abs(row[j] - row[j-1])

plt.plot(change)
fig.suptitle("Instability")
plt.ylabel('Weight change')
plt.xlabel('Revision')
