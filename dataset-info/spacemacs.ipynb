# %% [markdown]
# # Dataset analysis
# To generate results for every dataset in the `dataset` folder, run:
# ```
# for dataset in $(find dataset/* -maxdepth 0 -type d); do papermill dataset-info/DatasetBase.ipynb dataset-info/$(basename $dataset).ipynb -p input_dir $dataset; done
# ```

# %%
import matplotlib.pyplot as plt
import re, os
import papermill as pm
# %matplotlib inline

# %%
# Parameters
input_dir = "dataset/spacemacs"

# %%
# Make a regex to extract dataset name
import re

matchObj = re.match( r'.*/(.*)', input_dir, re.M|re.I)
if matchObj:
    dataset_id = matchObj.group(1)
    dataset_id

# %%
def natural_sort(l):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %%
# List files in input_dir in natural order
files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]
files = natural_sort(files)
files[0:5]
# Out:
# ['dataset/spacemacs/2012_12_31_2cc725f692da529791cf296170f5973b48f5cd4e.csv',
#  'dataset/spacemacs/2013_01_31_2333aa604a79251713e4b8d422e3a84dca5805ca.csv',
#  'dataset/spacemacs/2013_02_27_ddd1e7146f7431ecf61dcd076dcbc7a485183d90.csv',
#  'dataset/spacemacs/2013_03_24_f1f1b4e14e4c8fd178b8dd0947bd04ffe0b5f275.csv',
#  'dataset/spacemacs/2013_04_30_67df0c806edb4b1e671c7abed296af81ea97ee8b.csv']

# %%
import pandas as pd
n_revisions = len(files)
dfs = [pd.read_csv(file) for file in files]

# %%
dfs[0].head()
# Out:
#                                     id  weight
# 0    tensions/flymake/flymake-patch.el    1799
# 1                           c-lists.el     653
# 2            tensions/pymacs/pymacs.el     813
# 3  it-package/init-multiple-cursors.el     220
# 4                               ncs.el     125

# %%
from functools import reduce
# Outer join of files  
df_full = reduce((lambda x, y: pd.merge(x, y, how='outer', on='id')), dfs)

# %%
# Rename columns
df_full.columns = ['id'] + ['t'+str(i) for i in range(df_full.shape[1]-1)]

# %%
df_full.head()
# Out:
#                                     id      t0      t1      t2      t3  t4  \
# 0    tensions/flymake/flymake-patch.el  1799.0  1792.0  1792.0  1792.0 NaN
# 1                           c-lists.el   653.0   238.0   238.0   238.0 NaN
# 2            tensions/pymacs/pymacs.el   813.0   813.0   813.0   813.0 NaN
# 3  it-package/init-multiple-cursors.el   220.0     1.0     1.0     1.0 NaN
# 4                               ncs.el   125.0     NaN     NaN     NaN NaN
#
#    t5  t6  t7  t8 ...   t41  t42  t43  t44  t45  t46  t47  t48  t49  t50
# 0 NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1 NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2 NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3 NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4 NaN NaN NaN NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 52 columns]

# %%
from collections import defaultdict
import networkx as nx

FILE_MARKER = '<files>'

def attach(branch, trunk):
    parts = branch.split('/', 1)
    if len(parts) == 1:  # branch is a file
        trunk[FILE_MARKER].append(parts[0])
    else:
        node, others = parts
        if node not in trunk:
            trunk[node] = defaultdict(dict, ((FILE_MARKER, []),))
        attach(others, trunk[node])

def build_adjacency_list(d, id, result):
    for key in d.keys():
        if key != FILE_MARKER:
            result.append((id, id + key))
            build_adjacency_list(d[key], id + key, result)
        else:
            for file in d[key]:
                result.append((id, id + file))

        
def plot_tree(id_list):
    
    keys = sorted(id_list)

    main_dict = defaultdict(dict, ((FILE_MARKER, []),))
    for line in keys:
        attach(line, main_dict)

    # _create adjacency list
    result = []
    build_adjacency_list(main_dict, "ROOT", result)

    G = nx.DiGraph()
    G.add_edges_from(result)
    # write dot file to use with graphviz
    # run "dot -_tpng test.dot >test.png"
    # nx.nx_agraph.write_dot(_g, 'test.dot')

    # same layout using matplotlib with no labels
    pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
    nx.draw(G, pos, with_labels=False, arrows=False, node_size=2)

# %% [markdown]
# ## Union tree of all revisions

# %%
tree_fig = plt.figure(0)
tree_fig.suptitle(dataset_id)
plt.axis('off')
plot_tree(df_full['id'].tolist())
#pm.display('tree', tree_fig)

# %% [markdown]
# # Evolution

# %% [markdown]
# ## Items count

# %%
def plot_item_count():
    n_items = [len(df) for df in dfs]
    plt.plot(n_items)

fig = plt.figure()
fig.suptitle("Item count")
plt.ylabel('Number of items')
plt.xlabel('Revision')

plot_item_count()

# %% [markdown]
# ## Weight count

# %%
def plot_weight():
    total_weight = [sum(df['weight']) for df in dfs]
    plt.plot(total_weight)

fig = plt.figure()
fig.suptitle("Weight evolution")
plt.ylabel('Total weight')
plt.xlabel('Revision')
plot_weight()

# %% [markdown]
# ## Addition and removal of items

# %%
# How to find removals
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="left_only"')
# Out:
#                                                    id  weight_x  weight_y  \
# 4                                              ncs.el     125.0       NaN
# 7                                     nfig/session.el      99.0       NaN
# 12                                       ybindings.el      32.0       NaN
# 17  tensions/linum-relativenumber/linum-relativenu...      20.0       NaN
# 20                                         nfig/ui.el      18.0       NaN
# 23                                    nfig/editing.el      12.0       NaN
# 24                                 nfig/navigating.el      10.0       NaN
# 25                         it-package/init-ipython.el       9.0       NaN
# 27                it-package/init-highlight-symbol.el       6.0       NaN
# 39          it-extension/init-linum-relativenumber.el       2.0       NaN
#
#        _merge
# 4   left_only
# 7   left_only
# 12  left_only
# 17  left_only
# 20  left_only
# 23  left_only
# 24  left_only
# 25  left_only
# 27  left_only
# 39  left_only

# %%
# How to find additions
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="right_only"')
# len(pd.merge...) to get the number of additions/deletions
# Out:
#                                                    id  weight_x  weight_y  \
# 48                  tensions/elixir/samples/python.el       NaN    2731.0
# 49                      tensions/mu4e/mu4e-headers.el       NaN    1413.0
# 50                     tensions/distel/erl-service.el       NaN    1304.0
# 51                         tensions/mu4e/mu4e-view.el       NaN    1219.0
# 52                     tensions/distel/src/distel.erl       NaN    1098.0
# 53                             tensions/distel/edb.el       NaN     890.0
# 54                        tensions/mu4e/mu4e-utils.el       NaN     919.0
# 55                         tensions/mu4e/mu4e-vars.el       NaN     684.0
# 56                             tensions/distel/erl.el       NaN     653.0
# 57                            tensions/distel/derl.el       NaN     526.0
# 58                         tensions/mu4e/mu4e-proc.el       NaN     509.0
# 59                      tensions/mu4e/mu4e-compose.el       NaN     565.0
# 60                          tensions/distel/erlext.el       NaN     393.0
# 61                        tensions/mu4e/mu4e-draft.el       NaN     385.0
# 62                    tensions/distel/src/otp_doc.erl       NaN     338.0
# 63                         tensions/mu4e/mu4e-mark.el       NaN     337.0
# 64   tensions/centered-cursor/centered-cursor-mode.el       NaN     421.0
# 65                       tensions/distel/src/fdoc.erl       NaN     349.0
# 66                  tensions/distel/src/distel_ie.erl       NaN     392.0
# 67                         tensions/distel/net-fsm.el       NaN     272.0
# 68                          tensions/mu4e/org-mu4e.el       NaN     287.0
# 69                          tensions/distel/distel.el       NaN     282.0
# 70                        tensions/distel/patmatch.el       NaN     232.0
# 71                      tensions/mu4e/mu4e-message.el       NaN     227.0
# 72                       tensions/distel/distel-ie.el       NaN     234.0
# 73                      tensions/mu4e/mu4e-actions.el       NaN     234.0
# 74                                          -funcs.el       NaN     149.0
# 75                         tensions/mu4e/mu4e-main.el       NaN     168.0
# 76            tensions/evil-plugins/evil-mode-line.el       NaN      91.0
# 77                            tensions/distel/epmd.el       NaN     104.0
# ..                                                ...       ...       ...
# 100        st/QUE-WKS-AA427-Linux/additional-funcs.el       NaN      12.0
# 101                            nfig/config-editing.el       NaN      16.0
# 102               st/QUE-WKS-AA427-Linux/init-mu4e.el       NaN      12.0
# 103                          it-package/init-popup.el       NaN      11.0
# 104                           it-package/init-nose.el       NaN       9.0
# 105                         it-extension/init-edts.el       NaN      10.0
# 106                        it-package/init-recentf.el       NaN       7.0
# 107                                     -keychords.el       NaN      10.0
# 108                     it-extension/init-pylookup.el       NaN      10.0
# 109                            it-package/init-org.el       NaN       5.0
# 110                         nfig/config-navigation.el       NaN       7.0
# 111   it-extension/init-auto-highlight-symbol-mode.el       NaN       5.0
# 112                        tensions/mu4e/mu4e-meta.el       NaN       8.0
# 113                 it-extension/init-evil-plugins.el       NaN       7.0
# 114                    it-package/init-evil-leader.el       NaN       4.0
# 115        st/QUE-WKS-AA427-Linux/init-emacs-eclim.el       NaN       3.0
# 116               st/Qiao-MacBook/init-emacs-eclim.el       NaN       3.0
# 117                st/QUE-WKS-AA427-Linux/init-erc.el       NaN       6.0
# 118                     it-package/init-projectile.el       NaN       2.0
# 119                it-package/init-auto-dictionary.el       NaN       2.0
# 120                    it-extension/init-delim-pad.el       NaN       2.0
# 121  st/QUE-WKS-AA427-Linux/additional-keybindings.el       NaN       2.0
# 122                        it-package/init-rfringe.el       NaN       1.0
# 123                  it-extension/init-elixir-mode.el       NaN       1.0
# 124                                  stom-settings.el       NaN      25.0
# 125                       it-extension/init-elixir.el       NaN       1.0
# 126              it-extension/init-centered-cursor.el       NaN       1.0
# 127                      it-package/init-fold-this.el       NaN       1.0
# 128                   it-package/init-color-moccur.el       NaN       1.0
# 129                      it-package/init-move-text.el       NaN       1.0
#
#          _merge
# 48   right_only
# 49   right_only
# 50   right_only
# 51   right_only
# 52   right_only
# 53   right_only
# 54   right_only
# 55   right_only
# 56   right_only
# 57   right_only
# 58   right_only
# 59   right_only
# 60   right_only
# 61   right_only
# 62   right_only
# 63   right_only
# 64   right_only
# 65   right_only
# 66   right_only
# 67   right_only
# 68   right_only
# 69   right_only
# 70   right_only
# 71   right_only
# 72   right_only
# 73   right_only
# 74   right_only
# 75   right_only
# 76   right_only
# 77   right_only
# ..          ...
# 100  right_only
# 101  right_only
# 102  right_only
# 103  right_only
# 104  right_only
# 105  right_only
# 106  right_only
# 107  right_only
# 108  right_only
# 109  right_only
# 110  right_only
# 111  right_only
# 112  right_only
# 113  right_only
# 114  right_only
# 115  right_only
# 116  right_only
# 117  right_only
# 118  right_only
# 119  right_only
# 120  right_only
# 121  right_only
# 122  right_only
# 123  right_only
# 124  right_only
# 125  right_only
# 126  right_only
# 127  right_only
# 128  right_only
# 129  right_only
#
# [82 rows x 4 columns]

# %%
fig, ax = plt.subplots()

n_additions = []
n_removals = []
for i in range(1, n_revisions):
    n_additions.append(
        len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="right_only"')))
    n_removals.append(
        -len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="left_only"')))
x = range(0, n_revisions - 1)
ax.bar(x ,n_additions, width=1, color='b')
ax.bar(x, n_removals, width=1, color='r')

fig.suptitle("Item change evolution")
plt.ylabel('Removals - Additions')
plt.xlabel('Revision')

# %% [markdown]
# ## Sum of cell's change in weight (stability)

# %%
fig = plt.figure()
change = [0.0] * n_revisions
for index, row in df_full.fillna(0).iterrows():
    for j in range (2, len(row)):
        change[j-1] += abs(row[j] - row[j-1])

plt.plot(change)
fig.suptitle("Instability")
plt.ylabel('Weight change')
plt.xlabel('Revision')
