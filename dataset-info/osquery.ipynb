# %% [markdown]
# # Dataset analysis
# To generate results for every dataset in the `dataset` folder, run:
# ```
# for dataset in $(find dataset/* -maxdepth 0 -type d); do papermill dataset-info/DatasetBase.ipynb dataset-info/$(basename $dataset).ipynb -p input_dir $dataset; done
# ```

# %%
import matplotlib.pyplot as plt
import re, os
import papermill as pm
# %matplotlib inline

# %%
# Parameters
input_dir = "dataset/osquery"

# %%
# Make a regex to extract dataset name
import re

matchObj = re.match( r'.*/(.*)', input_dir, re.M|re.I)
if matchObj:
    dataset_id = matchObj.group(1)
    dataset_id

# %%
def natural_sort(l):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %%
# List files in input_dir in natural order
files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]
files = natural_sort(files)
files[0:5]
# Out:
# ['dataset/osquery/2014_07_30_3ab7342c24a33a4c99a0ea304ce7fa18dc0436d1.csv',
#  'dataset/osquery/2014_08_30_ffaa7632090a9bb8172f278a7846863af6a14b72.csv',
#  'dataset/osquery/2014_09_30_764619c8497a348f2095cd944529efa92532e834.csv',
#  'dataset/osquery/2014_10_31_eb240ac527a39fbc210bd68a1409f8cc8372121f.csv',
#  'dataset/osquery/2014_11_30_6a46513a085fb4590fe8aba862f8a94d0402a76f.csv']

# %%
import pandas as pd
n_revisions = len(files)
dfs = [pd.read_csv(file) for file in files]

# %%
dfs[0].head()
# Out:
#                            id  weight
# 0      query/sqlite/sqlite3.c  146388
# 1    query/devtools/shell.cpp    3861
# 2              ols/cpplint.py    5761
# 3             query/sqlite3.h    7386
# 4  query/database/results.cpp     316

# %%
from functools import reduce
# Outer join of files  
df_full = reduce((lambda x, y: pd.merge(x, y, how='outer', on='id')), dfs)

# %%
# Rename columns
df_full.columns = ['id'] + ['t'+str(i) for i in range(df_full.shape[1]-1)]

# %%
df_full.head()
# Out:
#                            id        t0      t1      t2      t3      t4  \
# 0      query/sqlite/sqlite3.c  146388.0     NaN     NaN     NaN     NaN
# 1    query/devtools/shell.cpp    3861.0  4078.0  4383.0  4401.0  4436.0
# 2              ols/cpplint.py    5761.0     NaN     NaN     NaN     NaN
# 3             query/sqlite3.h    7386.0     NaN     NaN     NaN     NaN
# 4  query/database/results.cpp     316.0   323.0   296.0   358.0   366.0
#
#        t5      t6      t7      t8   ...       t27     t28     t29     t30  \
# 0     NaN     NaN     NaN     NaN   ...       NaN     NaN     NaN     NaN
# 1  4450.0  4450.0  4445.0  2199.0   ...    1638.0  1631.0  1703.0  1723.0
# 2     NaN     NaN     NaN     NaN   ...       NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN   ...       NaN     NaN     NaN     NaN
# 4   384.0   383.0   383.0   414.0   ...       NaN     NaN     NaN     NaN
#
#       t31     t32     t33     t34     t35     t36
# 0     NaN     NaN     NaN     NaN     NaN     NaN
# 1  1738.0  1739.0  1739.0  1739.0  1739.0  1739.0
# 2     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 38 columns]

# %%
from collections import defaultdict
import networkx as nx

FILE_MARKER = '<files>'

def attach(branch, trunk):
    parts = branch.split('/', 1)
    if len(parts) == 1:  # branch is a file
        trunk[FILE_MARKER].append(parts[0])
    else:
        node, others = parts
        if node not in trunk:
            trunk[node] = defaultdict(dict, ((FILE_MARKER, []),))
        attach(others, trunk[node])

def build_adjacency_list(d, id, result):
    for key in d.keys():
        if key != FILE_MARKER:
            result.append((id, id + key))
            build_adjacency_list(d[key], id + key, result)
        else:
            for file in d[key]:
                result.append((id, id + file))

        
def plot_tree(id_list):
    
    keys = sorted(id_list)

    main_dict = defaultdict(dict, ((FILE_MARKER, []),))
    for line in keys:
        attach(line, main_dict)

    # _create adjacency list
    result = []
    build_adjacency_list(main_dict, "ROOT", result)

    G = nx.DiGraph()
    G.add_edges_from(result)
    # write dot file to use with graphviz
    # run "dot -_tpng test.dot >test.png"
    # nx.nx_agraph.write_dot(_g, 'test.dot')

    # same layout using matplotlib with no labels
    pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
    nx.draw(G, pos, with_labels=False, arrows=False, node_size=2)

# %% [markdown]
# ## Union tree of all revisions

# %%
tree_fig = plt.figure(0)
tree_fig.suptitle(dataset_id)
plt.axis('off')
plot_tree(df_full['id'].tolist())
#pm.display('tree', tree_fig)

# %% [markdown]
# # Evolution

# %% [markdown]
# ## Items count

# %%
def plot_item_count():
    n_items = [len(df) for df in dfs]
    plt.plot(n_items)

fig = plt.figure()
fig.suptitle("Item count")
plt.ylabel('Number of items')
plt.xlabel('Revision')

plot_item_count()

# %% [markdown]
# ## Weight count

# %%
def plot_weight():
    total_weight = [sum(df['weight']) for df in dfs]
    plt.plot(total_weight)

fig = plt.figure()
fig.suptitle("Weight evolution")
plt.ylabel('Total weight')
plt.xlabel('Revision')
plot_weight()

# %% [markdown]
# ## Addition and removal of items

# %%
# How to find removals
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="left_only"')
# Out:
#                                               id  weight_x  weight_y  \
# 0                         query/sqlite/sqlite3.c  146388.0       NaN
# 2                                 ols/cpplint.py    5761.0       NaN
# 3                                query/sqlite3.h    7386.0       NaN
# 16  query/tables/generated/generated_example.cpp     110.0       NaN
# 22              query/tables/generated_example.h      82.0       NaN
# 44                           query/core/status.h      25.0       NaN
# 46                           query/tables/hash.h      35.0       NaN
# 48                     query/tables/filesystem.h      35.0       NaN
# 50      query/tables/implementations/example.cpp      24.0       NaN
# 55        query/tables/implementations/example.h      14.0       NaN
#
#        _merge
# 0   left_only
# 2   left_only
# 3   left_only
# 16  left_only
# 22  left_only
# 44  left_only
# 46  left_only
# 48  left_only
# 50  left_only
# 55  left_only

# %%
# How to find additions
pd.merge(dfs[0], dfs[1], on='id', how='outer', indicator=True).query('_merge=="right_only"')
# len(pd.merge...) to get the number of additions/deletions
# Out:
#                                                    id  weight_x  weight_y  \
# 60                    query/tables/system/cacerts.cpp       NaN     395.0
# 61                   query/tables/system/firewall.cpp       NaN     226.0
# 62                          query/filesystem/plist.mm       NaN     171.0
# 63                      query/tables/system/nvram.cpp       NaN     179.0
# 64                   query/tables/system/kextstat.cpp       NaN     176.0
# 65                 query/tables/networking/routes.cpp       NaN     166.0
# 66                       query/tables/system/apps.cpp       NaN     141.0
# 67                    query/tables/system/launchd.cpp       NaN     134.0
# 68             query/tables/system/firewall_tests.cpp       NaN     127.0
# 69        query/tables/networking/listening_ports.cpp       NaN     137.0
# 70              query/tables/system/cacerts_tests.cpp       NaN     129.0
# 71                  query/tables/system/processes.cpp       NaN     140.0
# 72             query/tables/networking/interfaces.cpp       NaN     113.0
# 73                 query/tables/system/apps_tests.cpp       NaN      83.0
# 74                        query/tables/CMakeLists.txt       NaN      78.0
# 75                    query/filesystem/filesystem.cpp       NaN      80.0
# 76   query/core/osx/NSProcessInfo+PECocoaBackports.mm       NaN     102.0
# 77    query/core/osx/NSProcessInfo+PECocoaBackports.h       NaN      89.0
# 78               query/filesystem/plist_benchmark.cpp       NaN      63.0
# 79              query/tables/system/launchd_tests.cpp       NaN      55.0
# 80              query/filesystem/filesystem_tests.cpp       NaN      60.0
# 81                   query/filesystem/plist_tests.cpp       NaN      55.0
# 82              query/tables/networking/etc_hosts.cpp       NaN      56.0
# 83                    query/filesystem/CMakeLists.txt       NaN      45.0
# 84            query/core/osx/PECocoaBackportsGlobal.h       NaN      71.0
# 85                                   ols/gentables.py       NaN      61.0
# 86                  query/tables/networking/utils.cpp       NaN      53.0
# 87                          query/core/CMakeLists.txt       NaN      39.0
# 88                      query/database/CMakeLists.txt       NaN      36.0
# 89                                  ols/genpackage.py       NaN      45.0
# 90                                  ols/flag_test.cpp       NaN      36.0
# 91                              query/core/system.cpp       NaN      35.0
# 92               ckage/darwin/osquery_post_install.sh       NaN      34.0
# 93                            query/tables/registry.h       NaN      37.0
# 94                        query/core/init_osquery.cpp       NaN      29.0
# 95                          query/tables/registry.cpp       NaN      29.0
# 96                     query/tables/system/firewall.h       NaN      53.0
# 97                      query/tables/utility/time.cpp       NaN      30.0
# 98                 query/tables/system/osx_version.mm       NaN      33.0
# 99                                 query/filesystem.h       NaN      42.0
# 100                                       ols/run.cpp       NaN      28.0
# 101       query/tables/networking/etc_hosts_tests.cpp       NaN      29.0
# 102                             ols/registry_test.cpp       NaN      28.0
# 103                               query/core/text.cpp       NaN      25.0
# 104                                    query/status.h       NaN      26.0
# 105                         query/core/text_tests.cpp       NaN      26.0
# 106                       query/config/CMakeLists.txt       NaN      18.0
# 107                  query/tables/manual/filesystem.h       NaN      34.0
# 108                        query/tables/manual/hash.h       NaN      34.0
# 109                          query/core/sqlite_util.h       NaN      25.0
# 110                       query/logger/CMakeLists.txt       NaN      13.0
# 111                                ols/CMakeLists.txt       NaN      12.0
# 112                    query/scheduler/CMakeLists.txt       NaN       9.0
# 113                             ake/FindRocksDB.cmake       NaN       9.0
# 114                   query/tables/networking/utils.h       NaN      15.0
# 115                     query/devtools/CMakeLists.txt       NaN       6.0
# 116                             ake/FindSqlite3.cmake       NaN       2.0
# 117                               ake/FindGtest.cmake       NaN       2.0
#
#          _merge
# 60   right_only
# 61   right_only
# 62   right_only
# 63   right_only
# 64   right_only
# 65   right_only
# 66   right_only
# 67   right_only
# 68   right_only
# 69   right_only
# 70   right_only
# 71   right_only
# 72   right_only
# 73   right_only
# 74   right_only
# 75   right_only
# 76   right_only
# 77   right_only
# 78   right_only
# 79   right_only
# 80   right_only
# 81   right_only
# 82   right_only
# 83   right_only
# 84   right_only
# 85   right_only
# 86   right_only
# 87   right_only
# 88   right_only
# 89   right_only
# 90   right_only
# 91   right_only
# 92   right_only
# 93   right_only
# 94   right_only
# 95   right_only
# 96   right_only
# 97   right_only
# 98   right_only
# 99   right_only
# 100  right_only
# 101  right_only
# 102  right_only
# 103  right_only
# 104  right_only
# 105  right_only
# 106  right_only
# 107  right_only
# 108  right_only
# 109  right_only
# 110  right_only
# 111  right_only
# 112  right_only
# 113  right_only
# 114  right_only
# 115  right_only
# 116  right_only
# 117  right_only

# %%
fig, ax = plt.subplots()

n_additions = []
n_removals = []
for i in range(1, n_revisions):
    n_additions.append(
        len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="right_only"')))
    n_removals.append(
        -len(pd.merge(dfs[i-1], dfs[i], on='id', how='outer', indicator=True)
            .query('_merge=="left_only"')))
x = range(0, n_revisions - 1)
ax.bar(x ,n_additions, width=1, color='b')
ax.bar(x, n_removals, width=1, color='r')

fig.suptitle("Item change evolution")
plt.ylabel('Removals - Additions')
plt.xlabel('Revision')

# %% [markdown]
# ## Sum of cell's change in weight (stability)

# %%
fig = plt.figure()
change = [0.0] * n_revisions
for index, row in df_full.fillna(0).iterrows():
    for j in range (2, len(row)):
        change[j-1] += abs(row[j] - row[j-1])

plt.plot(change)
fig.suptitle("Instability")
plt.ylabel('Weight change')
plt.xlabel('Revision')
